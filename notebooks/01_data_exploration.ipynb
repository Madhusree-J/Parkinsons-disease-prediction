# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Path to dataset
csv_path = "../data/parkinsons_data.csv"

# Try to load real dataset, else generate dummy
import os
if os.path.exists(csv_path):
    df = pd.read_csv(csv_path)
    print("✅ Dataset loaded successfully:", df.shape)
else:
    print("⚠️ Dataset not found, generating dummy data for testing...")
    df = pd.DataFrame({
        'feature1': np.random.randn(50),
        'feature2': np.random.randn(50) * 2 + 1,
        'feature3': np.abs(np.random.randn(50)),
        'status': np.random.choice([0, 1], size=50)
    })
    print("Dummy dataset created:", df.shape)
# Out:
# ⚠️ Dataset not found, generating dummy data for testing...
# Dummy dataset created: (50, 4)

# %%
df.head()
# Out:
#    feature1  feature2  feature3  status
# 0  1.410357  3.534429  0.803042       0
# 1 -0.693109  2.681115  0.161470       1
# 2 -0.943902 -0.222489  0.850015       0
# 3  0.889933  3.092221  0.736918       1
# 4 -0.323454  2.711295  0.987437       1

# %%
print("Columns:", df.columns.tolist())
print("\nData types:\n", df.dtypes)
print("\nMissing values per column:\n", df.isnull().sum())
print("\nTarget distribution:\n", df['status'].value_counts(normalize=True))
# Out:
# Columns: ['feature1', 'feature2', 'feature3', 'status']
#
# Data types:
#  feature1    float64
# feature2    float64
# feature3    float64
# status        int64
# dtype: object
#
# Missing values per column:
#  feature1    0
# feature2    0
# feature3    0
# status      0
# dtype: int64
#
# Target distribution:
#  status
# 0    0.68
# 1    0.32
# Name: proportion, dtype: float64

# %%
display(df.describe().T)

plt.figure(figsize=(8,4))
sns.histplot(df['feature1'], kde=True)
plt.title("Feature1 Distribution")
plt.show()
# Out:
#           count      mean       std       min       25%       50%       75%  \
# feature1   50.0 -0.110054  0.906186 -1.725758 -0.899247 -0.128119  0.527402
# feature2   50.0  1.748341  2.419654 -4.562998  0.478417  1.937586  2.822847
# feature3   50.0  0.775902  0.591131  0.005385  0.277017  0.610422  1.088506
# status     50.0  0.520000  0.504672  0.000000  0.000000  1.000000  1.000000
#
#                max
# feature1  2.071288
# feature2  8.223299
# feature3  2.461841
# status    1.000000
